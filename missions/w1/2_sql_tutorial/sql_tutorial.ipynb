# %%
import sqlite3
import pandas as pd

# %%
def run_sql(statement, path='chinook.db'):
    try:
        with sqlite3.connect(path) as conn:
            cursor = conn.cursor()
            cursor.execute(statement)
            
            if statement.strip().lower().startswith("select"):
                rows = cursor.fetchall()
                columns = [description[0] for description in cursor.description]
                df = pd.DataFrame(rows, columns=columns)
                return df
            # conn.commit()
    except sqlite3.Error as e:
        return e

# %% [markdown]
# # Select all the records

# %%
statement = """
    SELECT * FROM Customers
"""

run_sql(statement)
# Out:
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# 21          22    Heather       Leacock
# 22          23       John        Gordon
# 23          24      Frank       Ralston
# 24          25     Victor       Stevens
# 25          26    Richard    Cunningham
# 26          27    Patrick          Gray
# 27          28      Julia       Barnett
# 28          29     Robert         Brown
# 29          30     Edward       Francis
# 30          31     Martha          Silk
# 31          32      Aaron      Mitchell
# 32          33      Ellie      Sullivan
# 33          34       João     Fernandes
# 34          35   Madalena       Sampaio
# 35          36     Hannah     Schneider
# 36          37       Fynn    Zimmermann
# 37          38     Niklas      Schröder
# 38          39    Camille       Bernard
# 39          40  Dominique      Lefebvre
# 40          41       Marc        Dubois
# 41          42      Wyatt        Girard
# 42          43   Isabelle       Mercier
# 43          44      Terhi    Hämäläinen
# 44          45   Ladislav        Kovács
# 45          46       Hugh      O'Reilly
# 46          47      Lucas       Mancini
# 47          48   Johannes  Van der Berg
# 48          49  Stanisław        Wójcik
# 49          50    Enrique         Muñoz
# 50          51     Joakim     Johansson
# 51          52       Emma         Jones
# 52          53       Phil        Hughes
# 53          54      Steve        Murray
# 54          55       Mark        Taylor
# 55          56      Diego     Gutiérrez
# 56          57       Luis         Rojas
# 57          58      Manoj        Pareek
# 58          59       Puja    Srivastava
#
#                                              Company  \
# 0   Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                             BaekSu
# 2                                             BaekSu
# 3                                             BaekSu
# 4                                   JetBrains s.r.o.
# 5                                             BaekSu
# 6                                             BaekSu
# 7                                             BaekSu
# 8                                             BaekSu
# 9                                   Woodstock Discos
# 10                              Banco do Brasil S.A.
# 11                                            Riotur
# 12                                            BaekSu
# 13                                             Telus
# 14                                     Rogers Canada
# 15                                       Google Inc.
# 16                             Microsoft Corporation
# 17                                            BaekSu
# 18                                        Apple Inc.
# 19                                            BaekSu
# 20                                            BaekSu
# 21                                            BaekSu
# 22                                            BaekSu
# 23                                            BaekSu
# 24                                            BaekSu
# 25                                            BaekSu
# 26                                            BaekSu
# 27                                            BaekSu
# 28                                            BaekSu
# 29                                            BaekSu
# 30                                            BaekSu
# 31                                            BaekSu
# 32                                            BaekSu
# 33                                            BaekSu
# 34                                            BaekSu
# 35                                            BaekSu
# 36                                            BaekSu
# 37                                            BaekSu
# 38                                            BaekSu
# 39                                            BaekSu
# 40                                            BaekSu
# 41                                            BaekSu
# 42                                            BaekSu
# 43                                            BaekSu
# 44                                            BaekSu
# 45                                            BaekSu
# 46                                            BaekSu
# 47                                            BaekSu
# 48                                            BaekSu
# 49                                            BaekSu
# 50                                            BaekSu
# 51                                            BaekSu
# 52                                            BaekSu
# 53                                            BaekSu
# 54                                            BaekSu
# 55                                            BaekSu
# 56                                            BaekSu
# 57                                            BaekSu
# 58                                            BaekSu
#
#                                      Address                 City   State  \
# 0            Av. Brigadeiro Faria Lima, 2170  São José dos Campos      SP
# 1                    Theodor-Heuss-Straße 34            Stuttgart    None
# 2                          1498 rue Bélanger             Montréal      QC
# 3                           Ullevålsveien 14                 Oslo    None
# 4                              Klanova 9/506               Prague    None
# 5                              Rilská 3174/6               Prague    None
# 6       Rotenturmstraße 4, 1010 Innere Stadt               Vienne    None
# 7                            Grétrystraat 63             Brussels    None
# 8                        Sønder Boulevard 51           Copenhagen    None
# 9                  Rua Dr. Falcão Filho, 155            São Paulo      SP
# 10                        Av. Paulista, 2022            São Paulo      SP
# 11                          Praça Pio X, 119       Rio de Janeiro      RJ
# 12                              Qe 7 Bloco G             Brasília      DF
# 13                            8210 111 ST NW             Edmonton      AB
# 14                       700 W Pender Street            Vancouver      BC
# 15                 1600 Amphitheatre Parkway        Mountain View      CA
# 16                           1 Microsoft Way              Redmond      WA
# 17                              627 Broadway             New York      NY
# 18                           1 Infinite Loop            Cupertino      CA
# 19                      541 Del Medio Avenue        Mountain View      CA
# 20                          801 W 4th Street                 Reno      NV
# 21                          120 S Orange Ave              Orlando      FL
# 22                           69 Salem Street               Boston      MA
# 23                     162 E Superior Street              Chicago      IL
# 24                     319 N. Frances Street              Madison      WI
# 25                       2211 W Berry Street           Fort Worth      TX
# 26                           1033 N Park Ave               Tucson      AZ
# 27                               302 S 700 E       Salt Lake City      UT
# 28                    796 Dundas Street West              Toronto      ON
# 29                          230 Elgin Street               Ottawa      ON
# 30                     194A Chain Lake Drive              Halifax      NS
# 31                        696 Osborne Street             Winnipeg      MB
# 32                            5112 48 Street          Yellowknife      NT
# 33                        Rua da Assunção 53               Lisbon    None
# 34  Rua dos Campeões Europeus de Viena, 4350                Porto    None
# 35                        Tauentzienstraße 8               Berlin    None
# 36                          Berger Straße 10            Frankfurt    None
# 37                       Barbarossastraße 19               Berlin    None
# 38                             4, Rue Milton                Paris    None
# 39                            8, Rue Hanovre                Paris    None
# 40                       11, Place Bellecour                 Lyon    None
# 41                    9, Place Louis Barthou             Bordeaux    None
# 42                          68, Rue Jouvence                Dijon    None
# 43                           Porthaninkatu 9             Helsinki    None
# 44                         Erzsébet krt. 58.             Budapest    None
# 45                          3 Chatham Street               Dublin  Dublin
# 46                    Via Degli Scipioni, 43                 Rome      RM
# 47                     Lijnbaansgracht 120bg            Amsterdam      VV
# 48                              Ordynacka 10               Warsaw    None
# 49                        C/ San Bernardo 85               Madrid    None
# 50                               Celsiusg. 9            Stockholm    None
# 51                         202 Hoxton Street               London    None
# 52                              113 Lupus St               London    None
# 53                            110 Raeburn Pl           Edinburgh     None
# 54                         421 Bourke Street               Sidney     NSW
# 55                        307 Macacha Güemes         Buenos Aires    None
# 56                           Calle Lira, 198             Santiago    None
# 57                       12,Community Centre                Delhi    None
# 58                         3,Raj Bhavan Road            Bangalore    None
#
#            Country  PostalCode                Phone                 Fax  \
# 0           Brazil   12227-000   +55 (12) 3923-5555  +55 (12) 3923-5566
# 1          Germany       70174     +49 0711 2842222                None
# 2           Canada     H2G 1A7    +1 (514) 721-4711                None
# 3           Norway        0171      +47 22 44 22 22                None
# 4   Czech Republic       14700     +420 2 4172 5555    +420 2 4172 5555
# 5   Czech Republic       14300     +420 2 4177 0449                None
# 6          Austria        1010       +43 01 5134505                None
# 7          Belgium        1000     +32 02 219 03 03                None
# 8          Denmark        1720       +453 3331 9991                None
# 9           Brazil   01007-010   +55 (11) 3033-5446  +55 (11) 3033-4564
# 10          Brazil   01310-200   +55 (11) 3055-3278  +55 (11) 3055-8131
# 11          Brazil   20040-020   +55 (21) 2271-7000  +55 (21) 2271-7070
# 12          Brazil   71020-677   +55 (61) 3363-5547  +55 (61) 3363-7855
# 13          Canada     T6G 2C7    +1 (780) 434-4554   +1 (780) 434-5565
# 14          Canada     V6C 1G8    +1 (604) 688-2255   +1 (604) 688-8756
# 15             USA  94043-1351    +1 (650) 253-0000   +1 (650) 253-0000
# 16             USA  98052-8300    +1 (425) 882-8080   +1 (425) 882-8081
# 17             USA  10012-2612    +1 (212) 221-3546   +1 (212) 221-4679
# 18             USA       95014    +1 (408) 996-1010   +1 (408) 996-1011
# 19             USA   94040-111    +1 (650) 644-3358                None
# 20             USA       89503    +1 (775) 223-7665                None
# 21             USA       32801    +1 (407) 999-7788                None
# 22             USA        2113    +1 (617) 522-1333                None
# 23             USA       60611    +1 (312) 332-3232                None
# 24             USA       53703    +1 (608) 257-0597                None
# 25             USA       76110    +1 (817) 924-7272                None
# 26             USA       85719    +1 (520) 622-4200                None
# 27             USA       84102    +1 (801) 531-7272                None
# 28          Canada     M6J 1V1    +1 (416) 363-8888                None
# 29          Canada     K2P 1L7    +1 (613) 234-3322                None
# 30          Canada     B3S 1C5    +1 (902) 450-0450                None
# 31          Canada     R3L 2B9    +1 (204) 452-6452                None
# 32          Canada     X1A 1N6    +1 (867) 920-2233                None
# 33        Portugal        None   +351 (213) 466-111                None
# 34        Portugal        None   +351 (225) 022-448                None
# 35         Germany       10789     +49 030 26550280                None
# 36         Germany       60316     +49 069 40598889                None
# 37         Germany       10779      +49 030 2141444                None
# 38          France       75009   +33 01 49 70 65 65                None
# 39          France       75002   +33 01 47 42 71 71                None
# 40          France       69002   +33 04 78 30 30 30                None
# 41          France       33000   +33 05 56 96 96 96                None
# 42          France       21000   +33 03 80 73 66 99                None
# 43         Finland       00530     +358 09 870 2000                None
# 44         Hungary      H-1073                 None                None
# 45         Ireland        None      +353 01 6792424                None
# 46           Italy       00192      +39 06 39733434                None
# 47     Netherlands        1016      +31 020 6223130                None
# 48          Poland      00-358     +48 22 828 37 39                None
# 49           Spain       28015      +34 914 454 454                None
# 50          Sweden       11230     +46 08-651 52 52                None
# 51  United Kingdom      N1 5LH    +44 020 7707 0707                None
# 52  United Kingdom    SW1V 3EN    +44 020 7976 5722                None
# 53  United Kingdom     EH4 1HH    +44 0131 315 3300                None
# 54       Australia        2010   +61 (02) 9332 3633                None
# 55       Argentina        1106  +54 (0)11 4311 4333                None
# 56           Chile        None    +56 (0)2 635 4444                None
# 57           India      110017    +91 0124 39883988                None
# 58           India      560001     +91 080 22289999                None
#
#                             Email  SupportRepId
# 0            luisg@embraer.com.br             3
# 1           leonekohler@surfeu.de             5
# 2             ftremblay@gmail.com             3
# 3           bjorn.hansen@yahoo.no             4
# 4        frantisekw@jetbrains.com             4
# 5                 hholy@gmail.com             5
# 6          astrid.gruber@apple.at             5
# 7           daan_peeters@apple.be             4
# 8           kara.nielsen@jubii.dk             4
# 9        eduardo@woodstock.com.br             4
# 10               alero@uol.com.br             5
# 11  roberto.almeida@riotur.gov.br             3
# 12       fernadaramos4@uol.com.br             4
# 13             mphilips12@shaw.ca             5
# 14            jenniferp@rogers.ca             3
# 15             fharris@google.com             4
# 16        jacksmith@microsoft.com             5
# 17              michelleb@aol.com             3
# 18               tgoyer@apple.com             3
# 19            dmiller@comcast.com             4
# 20            kachase@hotmail.com             5
# 21             hleacock@gmail.com             4
# 22         johngordon22@yahoo.com             4
# 23             fralston@gmail.com             3
# 24             vstevens@yahoo.com             5
# 25       ricunningham@hotmail.com             4
# 26           patrick.gray@aol.com             4
# 27            jubarnett@gmail.com             5
# 28               robbrown@shaw.ca             3
# 29            edfrancis@yachoo.ca             3
# 30           marthasilk@gmail.com             5
# 31         aaronmitchell@yahoo.ca             4
# 32         ellie.sullivan@shaw.ca             3
# 33            jfernandes@yahoo.pt             4
# 34              masampaio@sapo.pt             4
# 35      hannah.schneider@yahoo.de             5
# 36           fzimmermann@yahoo.de             3
# 37            nschroder@surfeu.de             3
# 38       camille.bernard@yahoo.fr             4
# 39    dominiquelefebvre@gmail.com             4
# 40        marc.dubois@hotmail.com             5
# 41          wyatt.girard@yahoo.fr             3
# 42      isabelle_mercier@apple.fr             3
# 43      terhi.hamalainen@apple.fi             3
# 44       ladislav_kovacs@apple.hu             3
# 45           hughoreilly@apple.ie             3
# 46         lucas.mancini@yahoo.it             5
# 47        johavanderberg@yahoo.nl             5
# 48         stanisław.wójcik@wp.pl             4
# 49         enrique_munoz@yahoo.es             5
# 50      joakim.johansson@yahoo.se             5
# 51         emma_jones@hotmail.com             3
# 52          phil.hughes@gmail.com             3
# 53          steve.murray@yahoo.uk             5
# 54           mark.taylor@yahoo.au             4
# 55       diego.gutierrez@yahoo.ar             4
# 56             luisrojas@yahoo.cl             5
# 57        manoj.pareek@rediff.com             3
# 58       puja_srivastava@yahoo.in             3

# %% [markdown]
# # SELECT

# %%
statement = """
    SELECT LastName, City FROM Customers
"""

run_sql(statement)
# Out:
#         LastName                 City
# 0      Gonçalves  São José dos Campos
# 1         Köhler            Stuttgart
# 2       Tremblay             Montréal
# 3         Hansen                 Oslo
# 4    Wichterlová               Prague
# 5           Holý               Prague
# 6         Gruber               Vienne
# 7        Peeters             Brussels
# 8        Nielsen           Copenhagen
# 9        Martins            São Paulo
# 10         Rocha            São Paulo
# 11       Almeida       Rio de Janeiro
# 12         Ramos             Brasília
# 13       Philips             Edmonton
# 14      Peterson            Vancouver
# 15        Harris        Mountain View
# 16         Smith              Redmond
# 17        Brooks             New York
# 18         Goyer            Cupertino
# 19        Miller        Mountain View
# 20         Chase                 Reno
# 21       Leacock              Orlando
# 22        Gordon               Boston
# 23       Ralston              Chicago
# 24       Stevens              Madison
# 25    Cunningham           Fort Worth
# 26          Gray               Tucson
# 27       Barnett       Salt Lake City
# 28         Brown              Toronto
# 29       Francis               Ottawa
# 30          Silk              Halifax
# 31      Mitchell             Winnipeg
# 32      Sullivan          Yellowknife
# 33     Fernandes               Lisbon
# 34       Sampaio                Porto
# 35     Schneider               Berlin
# 36    Zimmermann            Frankfurt
# 37      Schröder               Berlin
# 38       Bernard                Paris
# 39      Lefebvre                Paris
# 40        Dubois                 Lyon
# 41        Girard             Bordeaux
# 42       Mercier                Dijon
# 43    Hämäläinen             Helsinki
# 44        Kovács             Budapest
# 45      O'Reilly               Dublin
# 46       Mancini                 Rome
# 47  Van der Berg            Amsterdam
# 48        Wójcik               Warsaw
# 49         Muñoz               Madrid
# 50     Johansson            Stockholm
# 51         Jones               London
# 52        Hughes               London
# 53        Murray           Edinburgh
# 54        Taylor               Sidney
# 55     Gutiérrez         Buenos Aires
# 56         Rojas             Santiago
# 57        Pareek                Delhi
# 58    Srivastava            Bangalore

# %% [markdown]
# # SELECT DISTINCT

# %%
statement = """
    SELECT DISTINCT Country FROM Customers
"""

run_sql(statement)
# Out:
#            Country
# 0           Brazil
# 1          Germany
# 2           Canada
# 3           Norway
# 4   Czech Republic
# 5          Austria
# 6          Belgium
# 7          Denmark
# 8              USA
# 9         Portugal
# 10          France
# 11         Finland
# 12         Hungary
# 13         Ireland
# 14           Italy
# 15     Netherlands
# 16          Poland
# 17           Spain
# 18          Sweden
# 19  United Kingdom
# 20       Australia
# 21       Argentina
# 22           Chile
# 23           India

# %% [markdown]
# # WHERE

# %%
statement = """
    SELECT * FROM Customers
    WHERE Country='Brazil'
"""

run_sql(statement)
# Out:
#    CustomerId  FirstName   LastName  \
# 0           1       Luís  Gonçalves
# 1          10    Eduardo    Martins
# 2          11  Alexandre      Rocha
# 3          12    Roberto    Almeida
# 4          13   Fernanda      Ramos
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                  Woodstock Discos
# 2                              Banco do Brasil S.A.
# 3                                            Riotur
# 4                                            BaekSu
#
#                            Address                 City State Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil
# 1        Rua Dr. Falcão Filho, 155            São Paulo    SP  Brazil
# 2               Av. Paulista, 2022            São Paulo    SP  Brazil
# 3                 Praça Pio X, 119       Rio de Janeiro    RJ  Brazil
# 4                     Qe 7 Bloco G             Brasília    DF  Brazil
#
#   PostalCode               Phone                 Fax  \
# 0  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566
# 1  01007-010  +55 (11) 3033-5446  +55 (11) 3033-4564
# 2  01310-200  +55 (11) 3055-3278  +55 (11) 3055-8131
# 3  20040-020  +55 (21) 2271-7000  +55 (21) 2271-7070
# 4  71020-677  +55 (61) 3363-5547  +55 (61) 3363-7855
#
#                            Email  SupportRepId
# 0           luisg@embraer.com.br             3
# 1       eduardo@woodstock.com.br             4
# 2               alero@uol.com.br             5
# 3  roberto.almeida@riotur.gov.br             3
# 4       fernadaramos4@uol.com.br             4

# %% [markdown]
# # ORDER BY

# %%
statement = """
    SELECT * FROM Customers
    ORDER BY Country DESC, LastName
"""

run_sql(statement)
# Out:
#     CustomerId  FirstName      LastName  \
# 0           53       Phil        Hughes
# 1           52       Emma         Jones
# 2           54      Steve        Murray
# 3           28      Julia       Barnett
# 4           18   Michelle        Brooks
# 5           21      Kathy         Chase
# 6           26    Richard    Cunningham
# 7           23       John        Gordon
# 8           19        Tim         Goyer
# 9           27    Patrick          Gray
# 10          16      Frank        Harris
# 11          22    Heather       Leacock
# 12          20        Dan        Miller
# 13          24      Frank       Ralston
# 14          17       Jack         Smith
# 15          25     Victor       Stevens
# 16          51     Joakim     Johansson
# 17          50    Enrique         Muñoz
# 18          34       João     Fernandes
# 19          35   Madalena       Sampaio
# 20          49  Stanisław        Wójcik
# 21           4      Bjørn        Hansen
# 22          48   Johannes  Van der Berg
# 23          47      Lucas       Mancini
# 24          46       Hugh      O'Reilly
# 25          58      Manoj        Pareek
# 26          59       Puja    Srivastava
# 27          45   Ladislav        Kovács
# 28           2     Leonie        Köhler
# 29          36     Hannah     Schneider
# 30          38     Niklas      Schröder
# 31          37       Fynn    Zimmermann
# 32          39    Camille       Bernard
# 33          41       Marc        Dubois
# 34          42      Wyatt        Girard
# 35          40  Dominique      Lefebvre
# 36          43   Isabelle       Mercier
# 37          44      Terhi    Hämäläinen
# 38           9       Kara       Nielsen
# 39           6     Helena          Holý
# 40           5  František   Wichterlová
# 41          57       Luis         Rojas
# 42          29     Robert         Brown
# 43          30     Edward       Francis
# 44          32      Aaron      Mitchell
# 45          15   Jennifer      Peterson
# 46          14       Mark       Philips
# 47          31     Martha          Silk
# 48          33      Ellie      Sullivan
# 49           3   François      Tremblay
# 50          12    Roberto       Almeida
# 51           1       Luís     Gonçalves
# 52          10    Eduardo       Martins
# 53          13   Fernanda         Ramos
# 54          11  Alexandre         Rocha
# 55           8       Daan       Peeters
# 56           7     Astrid        Gruber
# 57          55       Mark        Taylor
# 58          56      Diego     Gutiérrez
#
#                                              Company  \
# 0                                             BaekSu
# 1                                             BaekSu
# 2                                             BaekSu
# 3                                             BaekSu
# 4                                             BaekSu
# 5                                             BaekSu
# 6                                             BaekSu
# 7                                             BaekSu
# 8                                         Apple Inc.
# 9                                             BaekSu
# 10                                       Google Inc.
# 11                                            BaekSu
# 12                                            BaekSu
# 13                                            BaekSu
# 14                             Microsoft Corporation
# 15                                            BaekSu
# 16                                            BaekSu
# 17                                            BaekSu
# 18                                            BaekSu
# 19                                            BaekSu
# 20                                            BaekSu
# 21                                            BaekSu
# 22                                            BaekSu
# 23                                            BaekSu
# 24                                            BaekSu
# 25                                            BaekSu
# 26                                            BaekSu
# 27                                            BaekSu
# 28                                            BaekSu
# 29                                            BaekSu
# 30                                            BaekSu
# 31                                            BaekSu
# 32                                            BaekSu
# 33                                            BaekSu
# 34                                            BaekSu
# 35                                            BaekSu
# 36                                            BaekSu
# 37                                            BaekSu
# 38                                            BaekSu
# 39                                            BaekSu
# 40                                  JetBrains s.r.o.
# 41                                            BaekSu
# 42                                            BaekSu
# 43                                            BaekSu
# 44                                            BaekSu
# 45                                     Rogers Canada
# 46                                             Telus
# 47                                            BaekSu
# 48                                            BaekSu
# 49                                            BaekSu
# 50                                            Riotur
# 51  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 52                                  Woodstock Discos
# 53                                            BaekSu
# 54                              Banco do Brasil S.A.
# 55                                            BaekSu
# 56                                            BaekSu
# 57                                            BaekSu
# 58                                            BaekSu
#
#                                      Address                 City   State  \
# 0                               113 Lupus St               London    None
# 1                          202 Hoxton Street               London    None
# 2                             110 Raeburn Pl           Edinburgh     None
# 3                                302 S 700 E       Salt Lake City      UT
# 4                               627 Broadway             New York      NY
# 5                           801 W 4th Street                 Reno      NV
# 6                        2211 W Berry Street           Fort Worth      TX
# 7                            69 Salem Street               Boston      MA
# 8                            1 Infinite Loop            Cupertino      CA
# 9                            1033 N Park Ave               Tucson      AZ
# 10                 1600 Amphitheatre Parkway        Mountain View      CA
# 11                          120 S Orange Ave              Orlando      FL
# 12                      541 Del Medio Avenue        Mountain View      CA
# 13                     162 E Superior Street              Chicago      IL
# 14                           1 Microsoft Way              Redmond      WA
# 15                     319 N. Frances Street              Madison      WI
# 16                               Celsiusg. 9            Stockholm    None
# 17                        C/ San Bernardo 85               Madrid    None
# 18                        Rua da Assunção 53               Lisbon    None
# 19  Rua dos Campeões Europeus de Viena, 4350                Porto    None
# 20                              Ordynacka 10               Warsaw    None
# 21                          Ullevålsveien 14                 Oslo    None
# 22                     Lijnbaansgracht 120bg            Amsterdam      VV
# 23                    Via Degli Scipioni, 43                 Rome      RM
# 24                          3 Chatham Street               Dublin  Dublin
# 25                       12,Community Centre                Delhi    None
# 26                         3,Raj Bhavan Road            Bangalore    None
# 27                         Erzsébet krt. 58.             Budapest    None
# 28                   Theodor-Heuss-Straße 34            Stuttgart    None
# 29                        Tauentzienstraße 8               Berlin    None
# 30                       Barbarossastraße 19               Berlin    None
# 31                          Berger Straße 10            Frankfurt    None
# 32                             4, Rue Milton                Paris    None
# 33                       11, Place Bellecour                 Lyon    None
# 34                    9, Place Louis Barthou             Bordeaux    None
# 35                            8, Rue Hanovre                Paris    None
# 36                          68, Rue Jouvence                Dijon    None
# 37                           Porthaninkatu 9             Helsinki    None
# 38                       Sønder Boulevard 51           Copenhagen    None
# 39                             Rilská 3174/6               Prague    None
# 40                             Klanova 9/506               Prague    None
# 41                           Calle Lira, 198             Santiago    None
# 42                    796 Dundas Street West              Toronto      ON
# 43                          230 Elgin Street               Ottawa      ON
# 44                        696 Osborne Street             Winnipeg      MB
# 45                       700 W Pender Street            Vancouver      BC
# 46                            8210 111 ST NW             Edmonton      AB
# 47                     194A Chain Lake Drive              Halifax      NS
# 48                            5112 48 Street          Yellowknife      NT
# 49                         1498 rue Bélanger             Montréal      QC
# 50                          Praça Pio X, 119       Rio de Janeiro      RJ
# 51           Av. Brigadeiro Faria Lima, 2170  São José dos Campos      SP
# 52                 Rua Dr. Falcão Filho, 155            São Paulo      SP
# 53                              Qe 7 Bloco G             Brasília      DF
# 54                        Av. Paulista, 2022            São Paulo      SP
# 55                           Grétrystraat 63             Brussels    None
# 56      Rotenturmstraße 4, 1010 Innere Stadt               Vienne    None
# 57                         421 Bourke Street               Sidney     NSW
# 58                        307 Macacha Güemes         Buenos Aires    None
#
#            Country  PostalCode                Phone                 Fax  \
# 0   United Kingdom    SW1V 3EN    +44 020 7976 5722                None
# 1   United Kingdom      N1 5LH    +44 020 7707 0707                None
# 2   United Kingdom     EH4 1HH    +44 0131 315 3300                None
# 3              USA       84102    +1 (801) 531-7272                None
# 4              USA  10012-2612    +1 (212) 221-3546   +1 (212) 221-4679
# 5              USA       89503    +1 (775) 223-7665                None
# 6              USA       76110    +1 (817) 924-7272                None
# 7              USA        2113    +1 (617) 522-1333                None
# 8              USA       95014    +1 (408) 996-1010   +1 (408) 996-1011
# 9              USA       85719    +1 (520) 622-4200                None
# 10             USA  94043-1351    +1 (650) 253-0000   +1 (650) 253-0000
# 11             USA       32801    +1 (407) 999-7788                None
# 12             USA   94040-111    +1 (650) 644-3358                None
# 13             USA       60611    +1 (312) 332-3232                None
# 14             USA  98052-8300    +1 (425) 882-8080   +1 (425) 882-8081
# 15             USA       53703    +1 (608) 257-0597                None
# 16          Sweden       11230     +46 08-651 52 52                None
# 17           Spain       28015      +34 914 454 454                None
# 18        Portugal        None   +351 (213) 466-111                None
# 19        Portugal        None   +351 (225) 022-448                None
# 20          Poland      00-358     +48 22 828 37 39                None
# 21          Norway        0171      +47 22 44 22 22                None
# 22     Netherlands        1016      +31 020 6223130                None
# 23           Italy       00192      +39 06 39733434                None
# 24         Ireland        None      +353 01 6792424                None
# 25           India      110017    +91 0124 39883988                None
# 26           India      560001     +91 080 22289999                None
# 27         Hungary      H-1073                 None                None
# 28         Germany       70174     +49 0711 2842222                None
# 29         Germany       10789     +49 030 26550280                None
# 30         Germany       10779      +49 030 2141444                None
# 31         Germany       60316     +49 069 40598889                None
# 32          France       75009   +33 01 49 70 65 65                None
# 33          France       69002   +33 04 78 30 30 30                None
# 34          France       33000   +33 05 56 96 96 96                None
# 35          France       75002   +33 01 47 42 71 71                None
# 36          France       21000   +33 03 80 73 66 99                None
# 37         Finland       00530     +358 09 870 2000                None
# 38         Denmark        1720       +453 3331 9991                None
# 39  Czech Republic       14300     +420 2 4177 0449                None
# 40  Czech Republic       14700     +420 2 4172 5555    +420 2 4172 5555
# 41           Chile        None    +56 (0)2 635 4444                None
# 42          Canada     M6J 1V1    +1 (416) 363-8888                None
# 43          Canada     K2P 1L7    +1 (613) 234-3322                None
# 44          Canada     R3L 2B9    +1 (204) 452-6452                None
# 45          Canada     V6C 1G8    +1 (604) 688-2255   +1 (604) 688-8756
# 46          Canada     T6G 2C7    +1 (780) 434-4554   +1 (780) 434-5565
# 47          Canada     B3S 1C5    +1 (902) 450-0450                None
# 48          Canada     X1A 1N6    +1 (867) 920-2233                None
# 49          Canada     H2G 1A7    +1 (514) 721-4711                None
# 50          Brazil   20040-020   +55 (21) 2271-7000  +55 (21) 2271-7070
# 51          Brazil   12227-000   +55 (12) 3923-5555  +55 (12) 3923-5566
# 52          Brazil   01007-010   +55 (11) 3033-5446  +55 (11) 3033-4564
# 53          Brazil   71020-677   +55 (61) 3363-5547  +55 (61) 3363-7855
# 54          Brazil   01310-200   +55 (11) 3055-3278  +55 (11) 3055-8131
# 55         Belgium        1000     +32 02 219 03 03                None
# 56         Austria        1010       +43 01 5134505                None
# 57       Australia        2010   +61 (02) 9332 3633                None
# 58       Argentina        1106  +54 (0)11 4311 4333                None
#
#                             Email  SupportRepId
# 0           phil.hughes@gmail.com             3
# 1          emma_jones@hotmail.com             3
# 2           steve.murray@yahoo.uk             5
# 3             jubarnett@gmail.com             5
# 4               michelleb@aol.com             3
# 5             kachase@hotmail.com             5
# 6        ricunningham@hotmail.com             4
# 7          johngordon22@yahoo.com             4
# 8                tgoyer@apple.com             3
# 9            patrick.gray@aol.com             4
# 10             fharris@google.com             4
# 11             hleacock@gmail.com             4
# 12            dmiller@comcast.com             4
# 13             fralston@gmail.com             3
# 14        jacksmith@microsoft.com             5
# 15             vstevens@yahoo.com             5
# 16      joakim.johansson@yahoo.se             5
# 17         enrique_munoz@yahoo.es             5
# 18            jfernandes@yahoo.pt             4
# 19              masampaio@sapo.pt             4
# 20         stanisław.wójcik@wp.pl             4
# 21          bjorn.hansen@yahoo.no             4
# 22        johavanderberg@yahoo.nl             5
# 23         lucas.mancini@yahoo.it             5
# 24           hughoreilly@apple.ie             3
# 25        manoj.pareek@rediff.com             3
# 26       puja_srivastava@yahoo.in             3
# 27       ladislav_kovacs@apple.hu             3
# 28          leonekohler@surfeu.de             5
# 29      hannah.schneider@yahoo.de             5
# 30            nschroder@surfeu.de             3
# 31           fzimmermann@yahoo.de             3
# 32       camille.bernard@yahoo.fr             4
# 33        marc.dubois@hotmail.com             5
# 34          wyatt.girard@yahoo.fr             3
# 35    dominiquelefebvre@gmail.com             4
# 36      isabelle_mercier@apple.fr             3
# 37      terhi.hamalainen@apple.fi             3
# 38          kara.nielsen@jubii.dk             4
# 39                hholy@gmail.com             5
# 40       frantisekw@jetbrains.com             4
# 41             luisrojas@yahoo.cl             5
# 42               robbrown@shaw.ca             3
# 43            edfrancis@yachoo.ca             3
# 44         aaronmitchell@yahoo.ca             4
# 45            jenniferp@rogers.ca             3
# 46             mphilips12@shaw.ca             5
# 47           marthasilk@gmail.com             5
# 48         ellie.sullivan@shaw.ca             3
# 49            ftremblay@gmail.com             3
# 50  roberto.almeida@riotur.gov.br             3
# 51           luisg@embraer.com.br             3
# 52       eduardo@woodstock.com.br             4
# 53       fernadaramos4@uol.com.br             4
# 54               alero@uol.com.br             5
# 55          daan_peeters@apple.be             4
# 56         astrid.gruber@apple.at             5
# 57           mark.taylor@yahoo.au             4
# 58       diego.gutierrez@yahoo.ar             4

# %% [markdown]
# # AND OR NOT

# %%
statement = """
    SELECT * FROM Customers
    WHERE Country='India' AND LastName LIKE 'P%'
"""

run_sql(statement)
# Out:
#    CustomerId FirstName LastName Company              Address   City State  \
# 0          58     Manoj   Pareek  BaekSu  12,Community Centre  Delhi  None
#
#   Country PostalCode              Phone   Fax                    Email  \
# 0   India     110017  +91 0124 39883988  None  manoj.pareek@rediff.com
#
#    SupportRepId
# 0             3

# %%
statement = """
    SELECT * FROM Customers
    WHERE Country='India' OR Country='Brazil'
"""

run_sql(statement)
# Out:
#    CustomerId  FirstName    LastName  \
# 0           1       Luís   Gonçalves
# 1          10    Eduardo     Martins
# 2          11  Alexandre       Rocha
# 3          12    Roberto     Almeida
# 4          13   Fernanda       Ramos
# 5          58      Manoj      Pareek
# 6          59       Puja  Srivastava
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                  Woodstock Discos
# 2                              Banco do Brasil S.A.
# 3                                            Riotur
# 4                                            BaekSu
# 5                                            BaekSu
# 6                                            BaekSu
#
#                            Address                 City State Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil
# 1        Rua Dr. Falcão Filho, 155            São Paulo    SP  Brazil
# 2               Av. Paulista, 2022            São Paulo    SP  Brazil
# 3                 Praça Pio X, 119       Rio de Janeiro    RJ  Brazil
# 4                     Qe 7 Bloco G             Brasília    DF  Brazil
# 5              12,Community Centre                Delhi  None   India
# 6                3,Raj Bhavan Road            Bangalore  None   India
#
#   PostalCode               Phone                 Fax  \
# 0  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566
# 1  01007-010  +55 (11) 3033-5446  +55 (11) 3033-4564
# 2  01310-200  +55 (11) 3055-3278  +55 (11) 3055-8131
# 3  20040-020  +55 (21) 2271-7000  +55 (21) 2271-7070
# 4  71020-677  +55 (61) 3363-5547  +55 (61) 3363-7855
# 5     110017   +91 0124 39883988                None
# 6     560001    +91 080 22289999                None
#
#                            Email  SupportRepId
# 0           luisg@embraer.com.br             3
# 1       eduardo@woodstock.com.br             4
# 2               alero@uol.com.br             5
# 3  roberto.almeida@riotur.gov.br             3
# 4       fernadaramos4@uol.com.br             4
# 5        manoj.pareek@rediff.com             3
# 6       puja_srivastava@yahoo.in             3

# %% [markdown]
# # INSERT INTO

# %%
statement = """
    INSERT INTO Customers (FirstName, LastName, Company, Country, Email)
    VALUES ('Gildong', 'Hong', 'Hyundai Motors Group', 'Republic of Korea', 'a@b.com');
"""

run_sql(statement)

statement = """
    SELECT * FROM Customers
    WHERE FirstName='Gildong';
"""

run_sql(statement)
# Out:
#    CustomerId FirstName LastName               Company Address  City State  \
# 0          64   Gildong     Hong  Hyundai Motors Group    None  None  None
#
#              Country PostalCode Phone   Fax    Email SupportRepId
# 0  Republic of Korea       None  None  None  a@b.com         None

# %% [markdown]
# # NULL Values

# %%
statement = """
    SELECT FirstName, LastName FROM Customers
    WHERE Company IS NOT NULL;
"""

run_sql(statement)
# Out:
#     FirstName      LastName
# 0        Luís     Gonçalves
# 1      Leonie        Köhler
# 2    François      Tremblay
# 3       Bjørn        Hansen
# 4   František   Wichterlová
# 5      Helena          Holý
# 6      Astrid        Gruber
# 7        Daan       Peeters
# 8        Kara       Nielsen
# 9     Eduardo       Martins
# 10  Alexandre         Rocha
# 11    Roberto       Almeida
# 12   Fernanda         Ramos
# 13       Mark       Philips
# 14   Jennifer      Peterson
# 15      Frank        Harris
# 16       Jack         Smith
# 17   Michelle        Brooks
# 18        Tim         Goyer
# 19        Dan        Miller
# 20      Kathy         Chase
# 21    Heather       Leacock
# 22       John        Gordon
# 23      Frank       Ralston
# 24     Victor       Stevens
# 25    Richard    Cunningham
# 26    Patrick          Gray
# 27      Julia       Barnett
# 28     Robert         Brown
# 29     Edward       Francis
# 30     Martha          Silk
# 31      Aaron      Mitchell
# 32      Ellie      Sullivan
# 33       João     Fernandes
# 34   Madalena       Sampaio
# 35     Hannah     Schneider
# 36       Fynn    Zimmermann
# 37     Niklas      Schröder
# 38    Camille       Bernard
# 39  Dominique      Lefebvre
# 40       Marc        Dubois
# 41      Wyatt        Girard
# 42   Isabelle       Mercier
# 43      Terhi    Hämäläinen
# 44   Ladislav        Kovács
# 45       Hugh      O'Reilly
# 46      Lucas       Mancini
# 47   Johannes  Van der Berg
# 48  Stanisław        Wójcik
# 49    Enrique         Muñoz
# 50     Joakim     Johansson
# 51       Emma         Jones
# 52       Phil        Hughes
# 53      Steve        Murray
# 54       Mark        Taylor
# 55      Diego     Gutiérrez
# 56       Luis         Rojas
# 57      Manoj        Pareek
# 58       Puja    Srivastava
# 59    Gildong          Hong

# %% [markdown]
# # UPDATE

# %%
statement = """
    UPDATE Customers
    SET Company='BaekSu'
    WHERE Company IS NULL
"""

run_sql(statement)

statement = """
    SELECT * FROM Customers
"""

run_sql(statement)
# Out:
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# 21          22    Heather       Leacock
# 22          23       John        Gordon
# 23          24      Frank       Ralston
# 24          25     Victor       Stevens
# 25          26    Richard    Cunningham
# 26          27    Patrick          Gray
# 27          28      Julia       Barnett
# 28          29     Robert         Brown
# 29          30     Edward       Francis
# 30          31     Martha          Silk
# 31          32      Aaron      Mitchell
# 32          33      Ellie      Sullivan
# 33          34       João     Fernandes
# 34          35   Madalena       Sampaio
# 35          36     Hannah     Schneider
# 36          37       Fynn    Zimmermann
# 37          38     Niklas      Schröder
# 38          39    Camille       Bernard
# 39          40  Dominique      Lefebvre
# 40          41       Marc        Dubois
# 41          42      Wyatt        Girard
# 42          43   Isabelle       Mercier
# 43          44      Terhi    Hämäläinen
# 44          45   Ladislav        Kovács
# 45          46       Hugh      O'Reilly
# 46          47      Lucas       Mancini
# 47          48   Johannes  Van der Berg
# 48          49  Stanisław        Wójcik
# 49          50    Enrique         Muñoz
# 50          51     Joakim     Johansson
# 51          52       Emma         Jones
# 52          53       Phil        Hughes
# 53          54      Steve        Murray
# 54          55       Mark        Taylor
# 55          56      Diego     Gutiérrez
# 56          57       Luis         Rojas
# 57          58      Manoj        Pareek
# 58          59       Puja    Srivastava
# 59          64    Gildong          Hong
#
#                                              Company  \
# 0   Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                             BaekSu
# 2                                             BaekSu
# 3                                             BaekSu
# 4                                   JetBrains s.r.o.
# 5                                             BaekSu
# 6                                             BaekSu
# 7                                             BaekSu
# 8                                             BaekSu
# 9                                   Woodstock Discos
# 10                              Banco do Brasil S.A.
# 11                                            Riotur
# 12                                            BaekSu
# 13                                             Telus
# 14                                     Rogers Canada
# 15                                       Google Inc.
# 16                             Microsoft Corporation
# 17                                            BaekSu
# 18                                        Apple Inc.
# 19                                            BaekSu
# 20                                            BaekSu
# 21                                            BaekSu
# 22                                            BaekSu
# 23                                            BaekSu
# 24                                            BaekSu
# 25                                            BaekSu
# 26                                            BaekSu
# 27                                            BaekSu
# 28                                            BaekSu
# 29                                            BaekSu
# 30                                            BaekSu
# 31                                            BaekSu
# 32                                            BaekSu
# 33                                            BaekSu
# 34                                            BaekSu
# 35                                            BaekSu
# 36                                            BaekSu
# 37                                            BaekSu
# 38                                            BaekSu
# 39                                            BaekSu
# 40                                            BaekSu
# 41                                            BaekSu
# 42                                            BaekSu
# 43                                            BaekSu
# 44                                            BaekSu
# 45                                            BaekSu
# 46                                            BaekSu
# 47                                            BaekSu
# 48                                            BaekSu
# 49                                            BaekSu
# 50                                            BaekSu
# 51                                            BaekSu
# 52                                            BaekSu
# 53                                            BaekSu
# 54                                            BaekSu
# 55                                            BaekSu
# 56                                            BaekSu
# 57                                            BaekSu
# 58                                            BaekSu
# 59                              Hyundai Motors Group
#
#                                      Address                 City   State  \
# 0            Av. Brigadeiro Faria Lima, 2170  São José dos Campos      SP
# 1                    Theodor-Heuss-Straße 34            Stuttgart    None
# 2                          1498 rue Bélanger             Montréal      QC
# 3                           Ullevålsveien 14                 Oslo    None
# 4                              Klanova 9/506               Prague    None
# 5                              Rilská 3174/6               Prague    None
# 6       Rotenturmstraße 4, 1010 Innere Stadt               Vienne    None
# 7                            Grétrystraat 63             Brussels    None
# 8                        Sønder Boulevard 51           Copenhagen    None
# 9                  Rua Dr. Falcão Filho, 155            São Paulo      SP
# 10                        Av. Paulista, 2022            São Paulo      SP
# 11                          Praça Pio X, 119       Rio de Janeiro      RJ
# 12                              Qe 7 Bloco G             Brasília      DF
# 13                            8210 111 ST NW             Edmonton      AB
# 14                       700 W Pender Street            Vancouver      BC
# 15                 1600 Amphitheatre Parkway        Mountain View      CA
# 16                           1 Microsoft Way              Redmond      WA
# 17                              627 Broadway             New York      NY
# 18                           1 Infinite Loop            Cupertino      CA
# 19                      541 Del Medio Avenue        Mountain View      CA
# 20                          801 W 4th Street                 Reno      NV
# 21                          120 S Orange Ave              Orlando      FL
# 22                           69 Salem Street               Boston      MA
# 23                     162 E Superior Street              Chicago      IL
# 24                     319 N. Frances Street              Madison      WI
# 25                       2211 W Berry Street           Fort Worth      TX
# 26                           1033 N Park Ave               Tucson      AZ
# 27                               302 S 700 E       Salt Lake City      UT
# 28                    796 Dundas Street West              Toronto      ON
# 29                          230 Elgin Street               Ottawa      ON
# 30                     194A Chain Lake Drive              Halifax      NS
# 31                        696 Osborne Street             Winnipeg      MB
# 32                            5112 48 Street          Yellowknife      NT
# 33                        Rua da Assunção 53               Lisbon    None
# 34  Rua dos Campeões Europeus de Viena, 4350                Porto    None
# 35                        Tauentzienstraße 8               Berlin    None
# 36                          Berger Straße 10            Frankfurt    None
# 37                       Barbarossastraße 19               Berlin    None
# 38                             4, Rue Milton                Paris    None
# 39                            8, Rue Hanovre                Paris    None
# 40                       11, Place Bellecour                 Lyon    None
# 41                    9, Place Louis Barthou             Bordeaux    None
# 42                          68, Rue Jouvence                Dijon    None
# 43                           Porthaninkatu 9             Helsinki    None
# 44                         Erzsébet krt. 58.             Budapest    None
# 45                          3 Chatham Street               Dublin  Dublin
# 46                    Via Degli Scipioni, 43                 Rome      RM
# 47                     Lijnbaansgracht 120bg            Amsterdam      VV
# 48                              Ordynacka 10               Warsaw    None
# 49                        C/ San Bernardo 85               Madrid    None
# 50                               Celsiusg. 9            Stockholm    None
# 51                         202 Hoxton Street               London    None
# 52                              113 Lupus St               London    None
# 53                            110 Raeburn Pl           Edinburgh     None
# 54                         421 Bourke Street               Sidney     NSW
# 55                        307 Macacha Güemes         Buenos Aires    None
# 56                           Calle Lira, 198             Santiago    None
# 57                       12,Community Centre                Delhi    None
# 58                         3,Raj Bhavan Road            Bangalore    None
# 59                                      None                 None    None
#
#               Country  PostalCode                Phone                 Fax  \
# 0              Brazil   12227-000   +55 (12) 3923-5555  +55 (12) 3923-5566
# 1             Germany       70174     +49 0711 2842222                None
# 2              Canada     H2G 1A7    +1 (514) 721-4711                None
# 3              Norway        0171      +47 22 44 22 22                None
# 4      Czech Republic       14700     +420 2 4172 5555    +420 2 4172 5555
# 5      Czech Republic       14300     +420 2 4177 0449                None
# 6             Austria        1010       +43 01 5134505                None
# 7             Belgium        1000     +32 02 219 03 03                None
# 8             Denmark        1720       +453 3331 9991                None
# 9              Brazil   01007-010   +55 (11) 3033-5446  +55 (11) 3033-4564
# 10             Brazil   01310-200   +55 (11) 3055-3278  +55 (11) 3055-8131
# 11             Brazil   20040-020   +55 (21) 2271-7000  +55 (21) 2271-7070
# 12             Brazil   71020-677   +55 (61) 3363-5547  +55 (61) 3363-7855
# 13             Canada     T6G 2C7    +1 (780) 434-4554   +1 (780) 434-5565
# 14             Canada     V6C 1G8    +1 (604) 688-2255   +1 (604) 688-8756
# 15                USA  94043-1351    +1 (650) 253-0000   +1 (650) 253-0000
# 16                USA  98052-8300    +1 (425) 882-8080   +1 (425) 882-8081
# 17                USA  10012-2612    +1 (212) 221-3546   +1 (212) 221-4679
# 18                USA       95014    +1 (408) 996-1010   +1 (408) 996-1011
# 19                USA   94040-111    +1 (650) 644-3358                None
# 20                USA       89503    +1 (775) 223-7665                None
# 21                USA       32801    +1 (407) 999-7788                None
# 22                USA        2113    +1 (617) 522-1333                None
# 23                USA       60611    +1 (312) 332-3232                None
# 24                USA       53703    +1 (608) 257-0597                None
# 25                USA       76110    +1 (817) 924-7272                None
# 26                USA       85719    +1 (520) 622-4200                None
# 27                USA       84102    +1 (801) 531-7272                None
# 28             Canada     M6J 1V1    +1 (416) 363-8888                None
# 29             Canada     K2P 1L7    +1 (613) 234-3322                None
# 30             Canada     B3S 1C5    +1 (902) 450-0450                None
# 31             Canada     R3L 2B9    +1 (204) 452-6452                None
# 32             Canada     X1A 1N6    +1 (867) 920-2233                None
# 33           Portugal        None   +351 (213) 466-111                None
# 34           Portugal        None   +351 (225) 022-448                None
# 35            Germany       10789     +49 030 26550280                None
# 36            Germany       60316     +49 069 40598889                None
# 37            Germany       10779      +49 030 2141444                None
# 38             France       75009   +33 01 49 70 65 65                None
# 39             France       75002   +33 01 47 42 71 71                None
# 40             France       69002   +33 04 78 30 30 30                None
# 41             France       33000   +33 05 56 96 96 96                None
# 42             France       21000   +33 03 80 73 66 99                None
# 43            Finland       00530     +358 09 870 2000                None
# 44            Hungary      H-1073                 None                None
# 45            Ireland        None      +353 01 6792424                None
# 46              Italy       00192      +39 06 39733434                None
# 47        Netherlands        1016      +31 020 6223130                None
# 48             Poland      00-358     +48 22 828 37 39                None
# 49              Spain       28015      +34 914 454 454                None
# 50             Sweden       11230     +46 08-651 52 52                None
# 51     United Kingdom      N1 5LH    +44 020 7707 0707                None
# 52     United Kingdom    SW1V 3EN    +44 020 7976 5722                None
# 53     United Kingdom     EH4 1HH    +44 0131 315 3300                None
# 54          Australia        2010   +61 (02) 9332 3633                None
# 55          Argentina        1106  +54 (0)11 4311 4333                None
# 56              Chile        None    +56 (0)2 635 4444                None
# 57              India      110017    +91 0124 39883988                None
# 58              India      560001     +91 080 22289999                None
# 59  Republic of Korea        None                 None                None
#
#                             Email  SupportRepId
# 0            luisg@embraer.com.br           3.0
# 1           leonekohler@surfeu.de           5.0
# 2             ftremblay@gmail.com           3.0
# 3           bjorn.hansen@yahoo.no           4.0
# 4        frantisekw@jetbrains.com           4.0
# 5                 hholy@gmail.com           5.0
# 6          astrid.gruber@apple.at           5.0
# 7           daan_peeters@apple.be           4.0
# 8           kara.nielsen@jubii.dk           4.0
# 9        eduardo@woodstock.com.br           4.0
# 10               alero@uol.com.br           5.0
# 11  roberto.almeida@riotur.gov.br           3.0
# 12       fernadaramos4@uol.com.br           4.0
# 13             mphilips12@shaw.ca           5.0
# 14            jenniferp@rogers.ca           3.0
# 15             fharris@google.com           4.0
# 16        jacksmith@microsoft.com           5.0
# 17              michelleb@aol.com           3.0
# 18               tgoyer@apple.com           3.0
# 19            dmiller@comcast.com           4.0
# 20            kachase@hotmail.com           5.0
# 21             hleacock@gmail.com           4.0
# 22         johngordon22@yahoo.com           4.0
# 23             fralston@gmail.com           3.0
# 24             vstevens@yahoo.com           5.0
# 25       ricunningham@hotmail.com           4.0
# 26           patrick.gray@aol.com           4.0
# 27            jubarnett@gmail.com           5.0
# 28               robbrown@shaw.ca           3.0
# 29            edfrancis@yachoo.ca           3.0
# 30           marthasilk@gmail.com           5.0
# 31         aaronmitchell@yahoo.ca           4.0
# 32         ellie.sullivan@shaw.ca           3.0
# 33            jfernandes@yahoo.pt           4.0
# 34              masampaio@sapo.pt           4.0
# 35      hannah.schneider@yahoo.de           5.0
# 36           fzimmermann@yahoo.de           3.0
# 37            nschroder@surfeu.de           3.0
# 38       camille.bernard@yahoo.fr           4.0
# 39    dominiquelefebvre@gmail.com           4.0
# 40        marc.dubois@hotmail.com           5.0
# 41          wyatt.girard@yahoo.fr           3.0
# 42      isabelle_mercier@apple.fr           3.0
# 43      terhi.hamalainen@apple.fi           3.0
# 44       ladislav_kovacs@apple.hu           3.0
# 45           hughoreilly@apple.ie           3.0
# 46         lucas.mancini@yahoo.it           5.0
# 47        johavanderberg@yahoo.nl           5.0
# 48         stanisław.wójcik@wp.pl           4.0
# 49         enrique_munoz@yahoo.es           5.0
# 50      joakim.johansson@yahoo.se           5.0
# 51         emma_jones@hotmail.com           3.0
# 52          phil.hughes@gmail.com           3.0
# 53          steve.murray@yahoo.uk           5.0
# 54           mark.taylor@yahoo.au           4.0
# 55       diego.gutierrez@yahoo.ar           4.0
# 56             luisrojas@yahoo.cl           5.0
# 57        manoj.pareek@rediff.com           3.0
# 58       puja_srivastava@yahoo.in           3.0
# 59                        a@b.com           NaN

# %% [markdown]
# # DELETE

# %%
statement = """
    DELETE FROM Customers
    WHERE FirstName='Gildong';
"""

run_sql(statement)

statement = """
    SELECT * FROM Customers
    WHERE FirstName='Gildong';
"""

run_sql(statement)
# Out:
# Empty DataFrame
# Columns: [CustomerId, FirstName, LastName, Company, Address, City, State, Country, PostalCode, Phone, Fax, Email, SupportRepId]
# Index: []

# %% [markdown]
# # SELECT TOP, LIMIT, FETCH FIRST
# TOP: MS SQL Server
# LIMIT: MySQL
# FETCH FIRST: Oracle

# %%
statement = """
    SELECT * FROM Customers
    LIMIT 3;
"""

run_sql(statement)
# Out:
#    CustomerId FirstName   LastName  \
# 0           1      Luís  Gonçalves
# 1           2    Leonie     Köhler
# 2           3  François   Tremblay
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                            BaekSu
# 2                                            BaekSu
#
#                            Address                 City State  Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP   Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart  None  Germany
# 2                1498 rue Bélanger             Montréal    QC   Canada
#
#   PostalCode               Phone                 Fax                  Email  \
# 0  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566   luisg@embraer.com.br
# 1      70174    +49 0711 2842222                None  leonekohler@surfeu.de
# 2    H2G 1A7   +1 (514) 721-4711                None    ftremblay@gmail.com
#
#    SupportRepId
# 0             3
# 1             5
# 2             3

# %% [markdown]
# # MIN() MAX()

# %%
statement = """
    SELECT MIN(FirstName) AS FastestName
    FROM Customers;
"""

run_sql(statement)
# Out:
#   FastestName
# 0       Aaron

# %% [markdown]
# # COUNT(), AVG(), SUM()

# %%
# fax번호가 null이 아닌 미국인 수
statement = """
    SELECT COUNT(Fax)
    FROM Customers
    WHERE Country='USA';
"""

run_sql(statement)
# Out:
#    COUNT(Fax)
# 0           4

# %%
statement = """
    SELECT COUNT(DISTINCT Country) AS [Number of Countries]
    From Customers;
"""

run_sql(statement)
# Out:
#    Number of Countries
# 0                   24

# %%
statement = """
    SELECT SUM(SupportRepId) AS SumOfSupportRepId
    FROM Customers;
"""

run_sql(statement)
# Out:
#    SumOfSupportRepId
# 0                233

# %%
statement = """
    SELECT AVG(SupportRepId) AS AverageOfSupportRepId
    FROM Customers
    WHERE Country='Brazil';
"""

run_sql(statement)
# Out:
#    AverageOfSupportRepId
# 0                    3.8

# %%
statement = """
    SELECT AVG(UnitPrice)
    FROM Invoice_Items;
"""

run_sql(statement)
# Out:
#    AVG(UnitPrice)
# 0        1.039554

# %% [markdown]
# # LIKE

# %%
# select all customers that have 'e' in the second position
statement = """
    SELECT * FROM Customers
    WHERE FirstName LIKE '_e%';
"""

run_sql(statement)
# Out:
#    CustomerId FirstName    LastName        Company                  Address  \
# 0           2    Leonie      Köhler         BaekSu  Theodor-Heuss-Straße 34
# 1           6    Helena        Holý         BaekSu            Rilská 3174/6
# 2          13  Fernanda       Ramos         BaekSu             Qe 7 Bloco G
# 3          15  Jennifer    Peterson  Rogers Canada      700 W Pender Street
# 4          22   Heather     Leacock         BaekSu         120 S Orange Ave
# 5          44     Terhi  Hämäläinen         BaekSu          Porthaninkatu 9
#
#         City State         Country PostalCode               Phone  \
# 0  Stuttgart  None         Germany      70174    +49 0711 2842222
# 1     Prague  None  Czech Republic      14300    +420 2 4177 0449
# 2   Brasília    DF          Brazil  71020-677  +55 (61) 3363-5547
# 3  Vancouver    BC          Canada    V6C 1G8   +1 (604) 688-2255
# 4    Orlando    FL             USA      32801   +1 (407) 999-7788
# 5   Helsinki  None         Finland      00530    +358 09 870 2000
#
#                   Fax                      Email  SupportRepId
# 0                None      leonekohler@surfeu.de             5
# 1                None            hholy@gmail.com             5
# 2  +55 (61) 3363-7855   fernadaramos4@uol.com.br             4
# 3   +1 (604) 688-8756        jenniferp@rogers.ca             3
# 4                None         hleacock@gmail.com             4
# 5                None  terhi.hamalainen@apple.fi             3

# %% [markdown]
# # Wildcards
#
# sqlite에서는 glob 사용해서 더 다양하게 할 수 있음\
# https://www.sqlitetutorial.net/sqlite-glob/
#
# |Symbol|Description
# -----|-----
# %	|Represents zero or more characters
# _	|Represents a single character
# []	|Represents any single character within the brackets *
# ^	|Represents any character not in the brackets *
# -	|Represents any single character within the specified range *
# {}	|Represents any escaped character **
#
# \* Not supported in PostgreSQL and MySQL databases.\
# ** Supported only in Oracle databases.

# %%
# select all customers whose first name is not start with A to T
statement = """
    SELECT * FROM Customers
    WHERE FirstName GLOB '[^A-T]*';
"""

run_sql(statement)
# Out:
#    CustomerId FirstName LastName Company                 Address      City  \
# 0          25    Victor  Stevens  BaekSu   319 N. Frances Street   Madison
# 1          42     Wyatt   Girard  BaekSu  9, Place Louis Barthou  Bordeaux
#
#   State Country PostalCode               Phone   Fax                  Email  \
# 0    WI     USA      53703   +1 (608) 257-0597  None     vstevens@yahoo.com
# 1  None  France      33000  +33 05 56 96 96 96  None  wyatt.girard@yahoo.fr
#
#    SupportRepId
# 0             5
# 1             3

# %% [markdown]
# # IN

# %%
statement = """
    SELECT * FROM Customers
    WHERE Country In ('Germany', 'United Kingdom')
"""

run_sql(statement)
# Out:
#    CustomerId FirstName    LastName Company                  Address  \
# 0           2    Leonie      Köhler  BaekSu  Theodor-Heuss-Straße 34
# 1          36    Hannah   Schneider  BaekSu       Tauentzienstraße 8
# 2          37      Fynn  Zimmermann  BaekSu         Berger Straße 10
# 3          38    Niklas    Schröder  BaekSu      Barbarossastraße 19
# 4          52      Emma       Jones  BaekSu        202 Hoxton Street
# 5          53      Phil      Hughes  BaekSu             113 Lupus St
# 6          54     Steve      Murray  BaekSu           110 Raeburn Pl
#
#          City State         Country PostalCode              Phone   Fax  \
# 0   Stuttgart  None         Germany      70174   +49 0711 2842222  None
# 1      Berlin  None         Germany      10789   +49 030 26550280  None
# 2   Frankfurt  None         Germany      60316   +49 069 40598889  None
# 3      Berlin  None         Germany      10779    +49 030 2141444  None
# 4      London  None  United Kingdom     N1 5LH  +44 020 7707 0707  None
# 5      London  None  United Kingdom   SW1V 3EN  +44 020 7976 5722  None
# 6  Edinburgh   None  United Kingdom    EH4 1HH  +44 0131 315 3300  None
#
#                        Email  SupportRepId
# 0      leonekohler@surfeu.de             5
# 1  hannah.schneider@yahoo.de             5
# 2       fzimmermann@yahoo.de             3
# 3        nschroder@surfeu.de             3
# 4     emma_jones@hotmail.com             3
# 5      phil.hughes@gmail.com             3
# 6      steve.murray@yahoo.uk             5

# %% [markdown]
# # BETWEEN

# %%
statement = """
    SELECT * FROM Customers
    WHERE Country BETWEEN 'Germany' AND 'United Kingdom'
"""

run_sql(statement)
# Out:
#     CustomerId  FirstName      LastName                Company  \
# 0            2     Leonie        Köhler                 BaekSu
# 1            4      Bjørn        Hansen                 BaekSu
# 2           16      Frank        Harris            Google Inc.
# 3           17       Jack         Smith  Microsoft Corporation
# 4           18   Michelle        Brooks                 BaekSu
# 5           19        Tim         Goyer             Apple Inc.
# 6           20        Dan        Miller                 BaekSu
# 7           21      Kathy         Chase                 BaekSu
# 8           22    Heather       Leacock                 BaekSu
# 9           23       John        Gordon                 BaekSu
# 10          24      Frank       Ralston                 BaekSu
# 11          25     Victor       Stevens                 BaekSu
# 12          26    Richard    Cunningham                 BaekSu
# 13          27    Patrick          Gray                 BaekSu
# 14          28      Julia       Barnett                 BaekSu
# 15          34       João     Fernandes                 BaekSu
# 16          35   Madalena       Sampaio                 BaekSu
# 17          36     Hannah     Schneider                 BaekSu
# 18          37       Fynn    Zimmermann                 BaekSu
# 19          38     Niklas      Schröder                 BaekSu
# 20          45   Ladislav        Kovács                 BaekSu
# 21          46       Hugh      O'Reilly                 BaekSu
# 22          47      Lucas       Mancini                 BaekSu
# 23          48   Johannes  Van der Berg                 BaekSu
# 24          49  Stanisław        Wójcik                 BaekSu
# 25          50    Enrique         Muñoz                 BaekSu
# 26          51     Joakim     Johansson                 BaekSu
# 27          52       Emma         Jones                 BaekSu
# 28          53       Phil        Hughes                 BaekSu
# 29          54      Steve        Murray                 BaekSu
# 30          58      Manoj        Pareek                 BaekSu
# 31          59       Puja    Srivastava                 BaekSu
#
#                                      Address            City   State  \
# 0                    Theodor-Heuss-Straße 34       Stuttgart    None
# 1                           Ullevålsveien 14            Oslo    None
# 2                  1600 Amphitheatre Parkway   Mountain View      CA
# 3                            1 Microsoft Way         Redmond      WA
# 4                               627 Broadway        New York      NY
# 5                            1 Infinite Loop       Cupertino      CA
# 6                       541 Del Medio Avenue   Mountain View      CA
# 7                           801 W 4th Street            Reno      NV
# 8                           120 S Orange Ave         Orlando      FL
# 9                            69 Salem Street          Boston      MA
# 10                     162 E Superior Street         Chicago      IL
# 11                     319 N. Frances Street         Madison      WI
# 12                       2211 W Berry Street      Fort Worth      TX
# 13                           1033 N Park Ave          Tucson      AZ
# 14                               302 S 700 E  Salt Lake City      UT
# 15                        Rua da Assunção 53          Lisbon    None
# 16  Rua dos Campeões Europeus de Viena, 4350           Porto    None
# 17                        Tauentzienstraße 8          Berlin    None
# 18                          Berger Straße 10       Frankfurt    None
# 19                       Barbarossastraße 19          Berlin    None
# 20                         Erzsébet krt. 58.        Budapest    None
# 21                          3 Chatham Street          Dublin  Dublin
# 22                    Via Degli Scipioni, 43            Rome      RM
# 23                     Lijnbaansgracht 120bg       Amsterdam      VV
# 24                              Ordynacka 10          Warsaw    None
# 25                        C/ San Bernardo 85          Madrid    None
# 26                               Celsiusg. 9       Stockholm    None
# 27                         202 Hoxton Street          London    None
# 28                              113 Lupus St          London    None
# 29                            110 Raeburn Pl      Edinburgh     None
# 30                       12,Community Centre           Delhi    None
# 31                         3,Raj Bhavan Road       Bangalore    None
#
#            Country  PostalCode               Phone                Fax  \
# 0          Germany       70174    +49 0711 2842222               None
# 1           Norway        0171     +47 22 44 22 22               None
# 2              USA  94043-1351   +1 (650) 253-0000  +1 (650) 253-0000
# 3              USA  98052-8300   +1 (425) 882-8080  +1 (425) 882-8081
# 4              USA  10012-2612   +1 (212) 221-3546  +1 (212) 221-4679
# 5              USA       95014   +1 (408) 996-1010  +1 (408) 996-1011
# 6              USA   94040-111   +1 (650) 644-3358               None
# 7              USA       89503   +1 (775) 223-7665               None
# 8              USA       32801   +1 (407) 999-7788               None
# 9              USA        2113   +1 (617) 522-1333               None
# 10             USA       60611   +1 (312) 332-3232               None
# 11             USA       53703   +1 (608) 257-0597               None
# 12             USA       76110   +1 (817) 924-7272               None
# 13             USA       85719   +1 (520) 622-4200               None
# 14             USA       84102   +1 (801) 531-7272               None
# 15        Portugal        None  +351 (213) 466-111               None
# 16        Portugal        None  +351 (225) 022-448               None
# 17         Germany       10789    +49 030 26550280               None
# 18         Germany       60316    +49 069 40598889               None
# 19         Germany       10779     +49 030 2141444               None
# 20         Hungary      H-1073                None               None
# 21         Ireland        None     +353 01 6792424               None
# 22           Italy       00192     +39 06 39733434               None
# 23     Netherlands        1016     +31 020 6223130               None
# 24          Poland      00-358    +48 22 828 37 39               None
# 25           Spain       28015     +34 914 454 454               None
# 26          Sweden       11230    +46 08-651 52 52               None
# 27  United Kingdom      N1 5LH   +44 020 7707 0707               None
# 28  United Kingdom    SW1V 3EN   +44 020 7976 5722               None
# 29  United Kingdom     EH4 1HH   +44 0131 315 3300               None
# 30           India      110017   +91 0124 39883988               None
# 31           India      560001    +91 080 22289999               None
#
#                         Email  SupportRepId
# 0       leonekohler@surfeu.de             5
# 1       bjorn.hansen@yahoo.no             4
# 2          fharris@google.com             4
# 3     jacksmith@microsoft.com             5
# 4           michelleb@aol.com             3
# 5            tgoyer@apple.com             3
# 6         dmiller@comcast.com             4
# 7         kachase@hotmail.com             5
# 8          hleacock@gmail.com             4
# 9      johngordon22@yahoo.com             4
# 10         fralston@gmail.com             3
# 11         vstevens@yahoo.com             5
# 12   ricunningham@hotmail.com             4
# 13       patrick.gray@aol.com             4
# 14        jubarnett@gmail.com             5
# 15        jfernandes@yahoo.pt             4
# 16          masampaio@sapo.pt             4
# 17  hannah.schneider@yahoo.de             5
# 18       fzimmermann@yahoo.de             3
# 19        nschroder@surfeu.de             3
# 20   ladislav_kovacs@apple.hu             3
# 21       hughoreilly@apple.ie             3
# 22     lucas.mancini@yahoo.it             5
# 23    johavanderberg@yahoo.nl             5
# 24     stanisław.wójcik@wp.pl             4
# 25     enrique_munoz@yahoo.es             5
# 26  joakim.johansson@yahoo.se             5
# 27     emma_jones@hotmail.com             3
# 28      phil.hughes@gmail.com             3
# 29      steve.murray@yahoo.uk             5
# 30    manoj.pareek@rediff.com             3
# 31   puja_srivastava@yahoo.in             3

# %% [markdown]
# # Aliases

# %% [markdown]
# # Joins

# %% [markdown]
# # UNION

# %% [markdown]
# # GROUP BY

# %% [markdown]
# # HAVING

# %% [markdown]
# # EXISTS

# %% [markdown]
# # ANY and ALL

# %% [markdown]
# # CASE

# %% [markdown]
# # Comments
